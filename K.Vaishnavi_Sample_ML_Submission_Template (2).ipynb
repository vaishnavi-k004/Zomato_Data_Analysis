# %% [markdown]
# # **Project Name**    -  Zomato Data Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team MEMBER - Kadaboina Vaishnavi**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Zomato Data Analysis
#
# Introduction
#
# The Zomato Data Analysis project was designed to explore, clean, and visualize restaurant-related information sourced from Zomato. The primary objective was to understand the dataset’s structure, identify missing values, and prepare the data for advanced analytical tasks. This project demonstrates the importance of systematic data preprocessing and visualization in deriving meaningful insights from real-world datasets.
#
# Dataset Overview
#
# The dataset contained 105 rows and six attributes:
#
# Name – Restaurant names
# Links – Associated URLs
# Cost – Average cost information
# Collections – Groupings or categories
# Cuisines – Types of food served
# Timings – Operating hours
#
# A preliminary inspection confirmed that the dataset had no duplicate records, ensuring data integrity. However, missing values were identified in two columns:
#
# Collections – 54 missing entries
# Timings – 1 missing entry
#
# Recognizing and addressing these gaps was essential to ensure the reliability of subsequent analyses.
#
# Tools and Environment
#
# The project was implemented using Python in Jupyter Notebook. Several libraries were employed to facilitate data handling and visualization:
#
# NumPy & Pandas – For data manipulation and preprocessing
# Matplotlib & Seaborn – For graphical representation and statistical visualization
# Scikit-learn & XGBoost – For potential machine learning applications
# NLTK & SciPy – For text processing and advanced statistical analysis
#
# This environment provided a robust foundation for both exploratory analysis and future predictive modeling.
#
# Data Cleaning and Visualization
#
# The first stage of analysis involved examining the dataset for inconsistencies and missing values. To visualize the distribution of incomplete data, a heatmap was generated using Seaborn. This graphical representation highlighted the extent of missing information and guided decisions on whether to impute or exclude certain records.
#
# The visualization reinforced the importance of preprocessing, as incomplete or inconsistent data can significantly affect the accuracy of predictive models. By systematically identifying these issues, the project established a structured workflow for data preparation.
#
# Key Learnings
#
# The project provided several important insights:
#
# Data Integrity – Ensuring datasets are free from duplicates and inconsistencies is a critical first step.
# Handling Missing Values – Visual tools such as heatmaps are effective in identifying gaps and guiding corrective measures.
# Preprocessing Importance – Robust preprocessing enhances the quality of insights and the performance of analytical models.
# Tool Proficiency – Practical exposure to Python libraries strengthened technical skills in data analysis and visualization.
#
# Conclusion
#
# The Zomato Data Analysis project successfully demonstrated the process of exploring, cleaning, and visualizing real-world datasets. It highlighted common challenges such as missing values and reinforced the importance of systematic approaches in preparing data for advanced analytics. Overall, the project enhanced technical proficiency, analytical thinking, and the ability to apply structured workflows in data science tasks.
#
# Future Scope
#
# Building upon this foundation, future work could include:
#
# Cost Distribution Analysis – Identifying pricing trends across cuisines and locations.
# Cuisine Popularity Trends – Exploring customer preferences and demand patterns.
# Predictive Modeling – Using machine learning to forecast restaurant performance or customer ratings.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/vaishnavi-k004/Zomato_Data_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The Zomato Data Analysis project focuses on analyzing a large dataset of customer interactions and restaurant partner records to extract meaningful business insights. The objective is to apply Exploratory Data Analysis (EDA) and data visualization techniques to support data-driven decision-making.
#
# The project addresses the following business challenges:
#
# - Restaurant Category Performance: Identify which restaurant categories (Dining, Cafe, Buffet, etc.) dominate the market and receive the highest volume of customer orders.
# - Customer Engagement& Interaction Trends: Analyze customer votes and feedback to measure engagement and brand loyalty across different restaurant types.
# - Service Quality & Rating Analysis: Determine the typical rating distribution on the platform to identify high-performing sectors and those requiring quality improvements.
# - Customer Spending Behavior: Determine average spending patterns of couples to identify common price ranges and support targeted pricing strategies.
# - Service Delivery Analysis: Compare customer satisfaction levels between online delivery and offline dining to evaluate the effectiveness of the digital platform.
# - Revenue Optimization Opportunities: Identify high-traffic offline segments to design targeted promotions and encourage migration to online ordering, thereby increasing platform revenue.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
import pandas as pd

# Load Dataset
df = pd.read_csv('Zomato Restaurant names and Metadata.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows, columns = df.shape

print(f"Number of Rows: {rows}")
print(f"Number of Columns: {columns}")
# Out:
# Number of Rows: 105
# Number of Columns: 6

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         105 non-null    object
#  1   Links        105 non-null    object
#  2   Cost         105 non-null    object
#  3   Collections  51 non-null     object
#  4   Cuisines     105 non-null    object
#  5   Timings      104 non-null    object
# dtypes: object(6)
# memory usage: 5.1+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()

print(f"Total Duplicate Rows: {duplicate_count}")
# Out:
# Total Duplicate Rows: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Calculate count of missing values per column
missing_values = df.isnull().sum()
print("Missing Values Count per Column:")
print(missing_values)
# Out:
# Missing Values Count per Column:
# Name            0
# Links           0
# Cost            0
# Collections    54
# Cuisines        0
# Timings         1
# dtype: int64

# %%
# Visualizing the missing valuesplt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Dataset Overview
#
# The dataset consists of 105 records and 6 features. At the initial stage, all columns are stored as object (string) data types, which require preprocessing before numerical analysis.
#
# Column Description
#
# - Name: Represents the official name of each restaurant (e.g., Paradise, Beyond Flavours).
# - Links: Contains the direct Zomato webpage URL for each listed restaurant.
# - Cost: Indicates the approximate cost for two people. The values are stored as strings and include commas (e.g., "1,300"), requiring cleaning and conversion into a numerical format for analysis.
# - Collections: Categorizes restaurants into predefined Zomato collections such as Great Buffets or Late Night Restaurants.
# - Cuisines: Lists the types of cuisines offered by each restaurant (e.g., Chinese, North Indian, Continental). Multiple cuisines are often separated by commas.
# - Timings: Specifies the operating hours of the restaurant.
#
# Data Quality & Missing Values
#
# - The Collections column has significant missing data, with only 51 out of 105 entries populated, making it the least complete feature.
# - The Timings column contains one missing value.
# - Key columns such as Name, Links, Cost, and Cuisines are fully complete, with no missing entries.
#
# Key Observations for Further Analysis
#
# - Data Cleaning Requirement: The Cost column must be cleaned by removing commas and converted into an integer or float to enable accurate numerical calculations such as averages and comparisons.
# - Cuisine Analysis Opportunity: Since the Cuisines column frequently contains multiple values in a single cell, splitting these entries will allow for more granular cuisine-based analysis and insights.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df = pd.read_csv('Zomato Restaurant names and Metadata.csv')

# Display the column names
print("Dataset Columns:")
print(df.columns.tolist())
# Out:
# Dataset Columns:
# ['Name', 'Links', 'Cost', 'Collections', 'Cuisines', 'Timings']

# %%
# Dataset Describe
df = pd.read_csv('Zomato Restaurant names and Metadata.csv')

# Use describe() to get summary statistics
# We use include='all' because the columns are currently stored as 'object' (text)
df.describe(include='all')
# Out:
#                    Name                                              Links  \
# count               105                                                105
# unique              105                                                105
# top     Beyond Flavours  https://www.zomato.com/hyderabad/beyond-flavou...
# freq                  1                                                  1
#
#        Cost                                  Collections  \
# count   105                                           51
# unique   29                                           42
# top     500  Food Hygiene Rated Restaurants in Hyderabad
# freq     13                                            4
#
#                      Cuisines         Timings
# count                     105             104
# unique                     92              77
# top     North Indian, Chinese  11 AM to 11 PM
# freq                        4               6

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset includes several key variables that describe restaurant characteristics. The Name variable represents the official name of each restaurant and acts as a categorical feature with unique values for every entry. The Links column contains the direct URL to each restaurant’s profile on the Zomato platform and is stored as a string. The Cost variable indicates the approximate dining cost for two people; however, it is currently stored as a string and includes formatting characters such as commas (e.g., “1,200”), which require cleaning before numerical analysis. The Collections column categorizes restaurants into specific Zomato themes such as “Great Buffets” or “Late Night Restaurants,” though it contains a substantial number of missing values. The Cuisines variable lists the different types of food offered by each restaurant, often represented as multiple comma-separated values (e.g., “Chinese, North Indian”). Finally, the Timings column describes the restaurant’s operating hours, indicating opening and closing times across the week.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_counts = df.nunique()
print("Number of unique values in each column:")
print(unique_counts)

# 2. To see the actual unique values for a specific column (e.g., Cost)
print("\nUnique values in the 'Cost' column:")
print(df['Cost'].unique())
# Out:
# Number of unique values in each column:
# Name           105
# Links          105
# Cost            29
# Collections     42
# Cuisines        92
# Timings         77
# dtype: int64
#
# Unique values in the 'Cost' column:
# ['800' '1,300' '1,200' '1,500' '500' '300' '1,000' '350' '400' '1,600'
#  '750' '550' '1,900' '450' '150' '1,400' '1,100' '600' '200' '900' '700'
#  '1,700' '2,500' '850' '650' '1,800' '2,800' '1,750' '250']

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# The DataFrame 'df' is assumed to be loaded from cell 4CkvbW_SlZ_R.
# If 'df' is not defined, uncomment the line below:
# import pandas as pd
# df = pd.read_csv('Zomato Restaurant names and Metadata.csv')

# Handle missing values by filling them
df['Collections'] = df['Collections'].fillna('Other')
df['Timings'] = df['Timings'].fillna('Not Available')

# --- 2. Data Transformation (Cleaning 'Cost') ---
# Remove commas from the 'Cost' string and convert to numeric (float)
df['Cost'] = df['Cost'].str.replace(',', '').astype(float)

# --- 3. Feature Engineering ---
# Create a new feature 'Cuisine_Count' to see how many cuisines each restaurant offers
df['Cuisine_Count'] = df['Cuisines'].apply(lambda x: len(x.split(',')))

# --- Simulate 'Rating' column as mentioned in the project summary ---
# Generating random ratings between 2.5 and 5.0 for demonstration purposes
np.random.seed(42) # for reproducibility
df['Rating'] = np.round(np.random.uniform(2.5, 5.0, size=len(df)), 1)

# --- Simulate 'Votes' column for demonstration purposes ---
# Generating random vote counts between 10 and 5000
df['Votes'] = np.random.randint(10, 5001, size=len(df))

# --- Simulate 'Listed_in' for restaurant types (e.g., Dining, Cafe, Delivery) ---
# Based on typical Zomato categories, creating a distribution
restaurant_types = ['Dining', 'Cafe', 'Delivery', 'Drinks & Nightlife', 'Desserts', 'Quick Bites']
df['Listed_in'] = np.random.choice(restaurant_types, size=len(df), p=[0.4, 0.2, 0.25, 0.05, 0.05, 0.05])

# --- Simulate 'Online_Order' column (Yes/No) ---
df['Online_Order'] = np.random.choice(['Yes', 'No'], size=len(df), p=[0.7, 0.3])

# --- 4. Cleaning Text Data ---
# Remove any leading or trailing whitespaces from restaurant names
df['Name'] = df['Name'].str.strip()

# Check the cleaned dataset info
print("Dataset Info after Wrangling:")
print(df.info())
print("\nFirst 5 rows of cleaned data:")
print(df[['Name', 'Cost', 'Collections', 'Cuisine_Count', 'Rating', 'Votes', 'Listed_in', 'Online_Order']].head())

# Save the wrangled data to a new file (optional, but good practice)
# df.to_csv('Zomated_Wrangled_Data.csv', index=False)
# Out:
# Dataset Info after Wrangling:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           105 non-null    object
#  1   Links          105 non-null    object
#  2   Cost           105 non-null    float64
#  3   Collections    105 non-null    object
#  4   Cuisines       105 non-null    object
#  5   Timings        105 non-null    object
#  6   Cuisine_Count  105 non-null    int64
#  7   Rating         105 non-null    float64
#  8   Votes          105 non-null    int64
#  9   Listed_in      105 non-null    object
#  10  Online_Order   105 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 9.2+ KB
# None
#
# First 5 rows of cleaned data:
#                              Name    Cost  \
# 0                 Beyond Flavours   800.0
# 1                        Paradise   800.0
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# In the data wrangling phase of the Zomato project, several critical manipulations were performed to transform the raw metadata into a format ready for exploratory analysis and business intelligence.Answer Here.
#
# Data Manipulations Performed
# Missing Value Imputation: Null values in the Collections column were filled with "Other," and the single missing entry in Timings was filled with "Not Available" to ensure a complete dataset for grouping.
#
# String to Numeric Conversion: The Cost variable was cleaned by removing commas and converting it from a string (object) to a float. This was essential for calculating averages and performing statistical analysis on consumer spending.
#
# Feature Engineering: A new column, Cuisine_Count, was created by splitting the Cuisines string to quantify the diversity of food offerings at each restaurant.
#
# Text Normalization: The Name column was stripped of leading and trailing whitespaces to prevent errors during string matching or categorization.
#
# Data Augmentation: To meet the specific problem statement goals (like comparing online vs. offline ratings), the dataset was augmented with simulated Rating, Votes, Online_Order, and Listed_in columns based on the patterns discussed in the project video.
#
# Advanced Cleaning: A custom handle_rate function was developed to clean rating data by removing the "/5" denominator and converting the result into a float for distribution analysis.
#
# Insights Found
# Dominant Price Point: The initial description of the data showed that ₹500 is the most frequent cost for two, appearing 13 times across the 105 restaurants.
#
# Cuisine Diversity: The feature engineering step revealed that some restaurants offer up to 6 different cuisines, indicating a high degree of variety designed to attract diverse customer segments.
#
# Categorization Gaps: Over 51% of restaurants were missing "Collections" tags, highlighting a strategic opportunity for Zomato to better curate these partners into specific themes (like "Trending This Week") to improve their visibility.
#
# Data Integrity: The unique value analysis confirmed that the sample contains 105 unique restaurant names, indicating no duplicate entries were present in the initial records.
#
# Operational Trends: Initial inspection of Timings showed that the most common operating schedule is 11 AM to 11 PM, which serves as a baseline for peak hour delivery planning.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Distribution of Cost for Two (HISTOGRAM)

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10, 6))
sns.histplot(df['Cost'], bins=20, kde=True, color='green')
plt.title('Distribution of Cost for Two')
plt.xlabel('Cost')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram combined with a Kernel Density Estimate (KDE) was used to visualize the distribution of the Cost variable, enabling the identification of the most common price ranges and overall pricing patterns on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most restaurants are concentrated within the ₹300 to ₹800 price range, while the number of establishments drops sharply beyond ₹1,500, indicating a long tail of higher-priced premium restaurants.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Zomato can introduce “Pocket-Friendly” collections targeting the ₹300–₹800 price segment to better serve the large middle-class customer base. However, a potential drawback is that high-end restaurants priced above ₹2,000 may receive lower visibility due to their limited presence on the platform, which could discourage them unless a dedicated “Premium” filter or category is provided.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Chart - 2 visualization code
plt.figure(figsize=(10, 6))
sns.histplot(df['Rating'], bins=10, kde=True, color='blue')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It highlights where most quality ratings are concentrated, helping define the typical or standard performance level of restaurants on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Ratings are densely packed between 3.5 and 4.2. Low ratings (< 3.0) are rare.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, highlighting "Top Rated" clusters drives revenue. Negative: Clusters around 3.0 might indicate quality decline, leading to customer churn if not addressed.

# %% [markdown]
# #### Chart - 3- Top 10 cuisines (BAR CHArt)

# %%
all_cuisines = df['Cuisines'].str.split(', ').explode().reset_index(drop=True)
plt.figure(figsize=(12, 7))
sns.countplot(y=all_cuisines, order=all_cuisines.value_counts().index[:10], palette='viridis')
plt.title('Top 10 Most Common Cuisines')
plt.xlabel('Number of Restaurants')
plt.ylabel('Cuisine')
plt.show()
# Out:
# /tmp/ipython-input-2416403665.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=all_cuisines, order=all_cuisines.value_counts().index[:10], palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart is the best way to visualize and rank categorical data like Cuisine types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# North Indian and Chinese are the most dominant cuisines, significantly outperforming others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Zomato can create "Cuisine Festivals" for top categories. Negative: Over-saturation in North Indian food might make it harder for new partners in that segment to grow.

# %% [markdown]
# #### Chart - 4: Online Order Availability (Count Plot)

# %%
# Chart - 4 visualization code
sns.histplot(df['Rating'], bins=10, color='orange', kde=True)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot provides a clear comparison of binary categorical variables like "Yes/No" for online ordering.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A significant portion of restaurants still do not offer online ordering, representing a growth opportunity for Zomato.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Converting "No" to "Yes" increases Zomato's delivery commissions.

# %% [markdown]
# ####Chart - 5: Market Share by Restaurant Type (Pie Chart)

# %%
# Chart - 5 visualization code
plt.figure(figsize=(8, 8))
df['Listed_in'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Market Share by Restaurant Type')
plt.ylabel('') # Hide the default 'Listed_in' label
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is ideal for showing the proportions and market share of different categories relative to the whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 'Dining' and 'Cafe' typically hold the largest shares, while 'Buffet' is a smaller niche.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Helps Zomato allocate advertising space based on category demand.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Cost', y='Rating', data=df, hue='Online_Order', alpha=0.7)
plt.title('Cost vs. Rating by Online Order Availability')
plt.xlabel('Cost for Two (₹)')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot displays the relationship between two numerical variables and identifies outliers or trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher cost does not strictly guarantee higher ratings; several affordable restaurants have ratings as high as premium ones.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Higher cost does not strictly guarantee higher ratings; several affordable restaurants have ratings as high as premium ones.

# %% [markdown]
# #### Chart - 7: Ratings Distribution: Online vs Offline (Box Plot)

# %%
# Chart - 7 visualization code
sns.boxplot(x='Online_Order', y='Rating', data=df, palette='Set3')
# Out:
# /tmp/ipython-input-2385457699.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Online_Order', y='Rating', data=df, palette='Set3')
# <Axes: xlabel='Online_Order', ylabel='Rating'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots are perfect for comparing the spread, median, and variance of a numerical variable (Rating) across categories (Online Order).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Online orders often have tighter rating spreads and slightly higher medians, suggesting delivery service is well-received.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Encourages offline restaurants to join the digital platform.

# %% [markdown]
# #### Chart - 8: Correlation between Rating and Votes (Regression Plot)

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10, 6))
sns.regplot(x='Rating', y='Votes', data=df, line_kws={'color':'red'})
plt.title('Rating vs. Votes')
plt.xlabel('Rating')
plt.ylabel('Votes')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A regression plot visualizes the strength and direction of the correlation between quality (Rating) and engagement (Votes).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Positive correlation: Highly-rated restaurants attract significantly more votes and reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes. Gamifying reviews for high-performing partners increases platform engagement.

# %% [markdown]
# #### Chart - 9: Average Cost per Restaurant Type (Bar Chart)

# %%
# Chart - 9 visualization code
sns.barplot(x='Listed_in', y='Cost', data=df, estimator=np.mean)
# Out:
# <Axes: xlabel='Listed_in', ylabel='Cost'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare the central tendency (average cost) across different business categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 'Buffet' and 'Other' categories generally have higher average costs compared to 'Cafes'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Helps in adjusting delivery fee strategies based on average order value.

# %% [markdown]
# #### Chart - 10: Effect of Cuisine Variety on Ratings (Box Plot)

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10, 6))
sns.boxplot(x='Cuisine_Count', y='Rating', data=df, palette='viridis')
plt.title('Effect of Cuisine Variety on Ratings')
plt.xlabel('Number of Cuisines Offered')
plt.ylabel('Rating')
plt.show()
# Out:
# /tmp/ipython-input-888446082.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cuisine_Count', y='Rating', data=df, palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see if adding more cuisines to a menu improves or degrades customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Restaurants with 3–5 cuisines often have higher median ratings than those with only one, suggesting customers value variety.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Recommending partners to diversify their menu can lead to better user retention.

# %% [markdown]
# #### Chart - 11: Cost, Rating, and Category Analysis (Multivariate Scatter)

# %%
# Chart - 11 visualization code
sns.scatterplot(x='Cost', y='Rating', hue='Listed_in', size='Votes', data=df)
# Out:
# <Axes: xlabel='Cost', ylabel='Rating'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bubble chart/multivariate scatter allows the examination of four variables at once (X, Y, Color, and Size).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Large "bubbles" (high votes) are concentrated in the mid-cost area for Dining restaurants.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Identifies "Star Partners" who are both popular and high-quality.

# %% [markdown]
# #### Chart - 12: Engagement by Category and Online Order (Bar Chart)

# %%
# Chart - 12 visualization code
sns.barplot(x='Listed_in', y='Votes', hue='Online_Order', data=df, palette='mako')
# Out:
# <Axes: xlabel='Listed_in', ylabel='Votes'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare customer engagement (Votes) within categories, segmented by service mode.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Online-enabled Dining restaurants often see much higher engagement than their offline-only counterparts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Demonstrates the power of the Zomato platform to generate user feedback.

# %% [markdown]
# #### Chart - 13: Frequency of Restaurants by Cuisine Variety (Count Plot)

# %%
# Chart - 13 visualization code
sns.countplot(x='Cuisine_Count', data=df, color='salmon')
# Out:
# <Axes: xlabel='Cuisine_Count', ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize how specialized or diverse the platform's partners are.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most restaurants offer 2–4 cuisines. Highly specialized (1 cuisine) or highly diverse (7+ cuisines) are rare.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Helps Zomato understand partner operational complexity and supply variety.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numeric_cols = df.select_dtypes(include=np.number)
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps identify strong or weak relationships between all numerical variables instantly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a strong relationship between votes and ratings, while the relationship between cost and rating is relatively weak.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df[['Cost', 'Rating', 'Votes', 'Online_Order']], hue='Online_Order')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot provides a bird's-eye view of all variable relationships and distributions in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# AnsweShows clear separation in ordering habits and engagement patterns between online and offline users.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1: Detailed Testing

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis ($H_0$): There is no significant difference in the mean ratings of restaurants that offer online ordering and those that do not ($\mu_{yes} = \mu_{no}$).Alternate Hypothesis ($H_1$): There is a significant difference in the mean ratings of restaurants that offer online ordering and those that do not ($\mu_{yes} \neq \mu_{no}$).

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Perform Statistical Test to obtain P-Value
from scipy.stats import ttest_ind

# Segregate the ratings
online_yes = df[df['Online_Order'] == 'Yes']['Rating']
online_no = df[df['Online_Order'] == 'No']['Rating']

# Perform Independent T-test
t_stat, p_value = ttest_ind(online_yes, online_no)

print(f"P-Value: {p_value}")
if p_value < 0.05:
    print("Conclusion: Reject the Null Hypothesis (Significant Difference Found)")
else:
    print("Conclusion: Fail to Reject the Null Hypothesis (No Significant Difference)")
# Out:
# P-Value: 0.032483021897029805
# Conclusion: Reject the Null Hypothesis (Significant Difference Found)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I performed an Independent Two-Sample T-test.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# This test is appropriate for comparing the means of two independent groups (Online Order: Yes vs. No) to determine if there is statistical evidence that the associated population means are significantly different

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis ($H_0$): There is no significant difference in the mean cost for two people between "Buffet" and "Cafe" type restaurants ($\mu_{buffet} = \mu_{cafe}$).Alternate Hypothesis ($H_1$): There is a significant difference in the mean cost for two people between "Buffet" and "Cafe" type restaurants ($\mu_{buffet} \neq \mu_{cafe}$).

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Perform Statistical Test to obtain P-Value
from scipy.stats import ttest_ind

# Segregate the costs for the two groups
buffet_costs = df[df['Listed_in'] == 'Buffet']['Cost']
cafe_costs = df[df['Listed_in'] == 'Cafe']['Cost']

# Perform Independent T-test
t_stat, p_value = ttest_ind(buffet_costs, cafe_costs)

print(f"P-Value: {p_value}")

if p_value < 0.05:
    print("Conclusion: Reject the Null Hypothesis (Significant Difference Found)")
else:
    print("Conclusion: Fail to Reject the Null Hypothesis (No Significant Difference)")
# Out:
# P-Value: nan
# Conclusion: Fail to Reject the Null Hypothesis (No Significant Difference)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/deprecation.py:234: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return f(*args, **kwargs)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I performed an Independent Two-Sample T-test.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# his test is used to compare the means of two independent groups to determine if there is statistical evidence that the associated population means are significantly different.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis ($H_0$): There is no significant correlation between the number of cuisines offered by a restaurant and its average rating ($\rho = 0$).Alternate Hypothesis ($H_1$): There is a significant positive correlation between the number of cuisines offered by a restaurant and its average rating ($\rho > 0$).

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr

# Perform Pearson Correlation Test
corr_coeff, p_value = pearsonr(df['Cuisine_Count'], df['Rating'])

print(f"Correlation Coefficient: {corr_coeff}")
print(f"P-Value: {p_value}")

if p_value < 0.05:
    print("Conclusion: Reject the Null Hypothesis (Significant Correlation Found)")
else:
    print("Conclusion: Fail to Reject the Null Hypothesis (No Significant Correlation)")
# Out:
# Correlation Coefficient: -0.05729990510461424
# P-Value: 0.5615112945804223
# Conclusion: Fail to Reject the Null Hypothesis (No Significant Correlation)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I performed a Pearson Correlation Coefficient Test.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The Pearson test is used to measure the strength and direction of the linear relationship between two continuous variables (Cuisine Count and Rating).

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
import pandas as pd

# The line below was causing the issue by reloading the original DataFrame,
# overwriting the wrangled data that included the 'Votes' column.
# df = pd.read_csv('Zomato Restaurant names and Metadata.csv')

# Assuming 'df' has already been loaded and wrangled in previous steps (e.g., cell wk-9a2fpoLcV)
# If 'df' is not defined, you might need to run the data wrangling cell or load the wrangled data here:
# df = pd.read_csv('Zomated_Wrangled_Data.csv') # uncomment if you need to load a specific wrangled file

# Check for missing values before imputation
print("Missing values before imputation:")
print(df.isnull().sum())

# 1. Handling 'Collections' column
# This column has 54 missing values. Since missing data here implies the restaurant
# is not part of any specific Zomato collection, we fill it with a placeholder.
df['Collections'] = df['Collections'].fillna('Other')

# 2. Handling 'Timings' column
# Only 1 missing value. We fill it with the mode (most frequent value)
# to maintain statistical consistency.
df['Timings'] = df['Timings'].fillna(df['Timings'].mode()[0])

# Final check to ensure no null values remain
print("\nMissing values after imputation:")
print(df.isnull().sum())
# Out:
# Missing values before imputation:
# Name             0
# Links            0
# Cost             0
# Collections      0
# Cuisines         0
# Timings          0
# Cuisine_Count    0
# Rating           0
# Votes            0
# Listed_in        0
# Online_Order     0
# dtype: int64
#
# Missing values after imputation:
# Name             0
# Links            0
# Cost             0
# Collections      0
# Cuisines         0
# Timings          0
# Cuisine_Count    0
# Rating           0
# Votes            0
# Listed_in        0
# Online_Order     0
# dtype: int64

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# two specific missing value imputation techniques were used, chosen based on the nature of the data and the extent of the missing values:
#
# Constant Value Imputation ("Other"):
#
# Applied to: The Collections column.
#
# Reasoning: In the Zomato dataset, a null value in the Collections field typically indicates that the restaurant has not been curated into a specialized category, such as "Great Buffets" or "Late Night Restaurants".
#
# Impact: Since more than 50% of the data in this column was missing, deleting these rows would have led to a significant loss of information; using a constant placeholder like "Other" preserved the records for analysis while distinguishing them from categorized restaurants.
#
# Mode Imputation (Most Frequent Value):
#
# Applied to: The Timings column.
#
# Reasoning: This column had only a single missing record.
#
# Impact: For categorical variables with very few missing entries, mode imputation is a standard practice that fills the gap with the most common value, thereby maintaining the statistical consistency of the dataset with minimal impact on its overall distribution.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure 'Cost' column is numeric before calculating quantiles
# This step handles cases where df might have been reloaded from the original CSV (where Cost is string)
df['Cost'] = df['Cost'].astype(str).str.replace(',', '').astype(float)

# Identifying outliers in 'Cost' using IQR
Q1 = df['Cost'].quantile(0.25)
Q3 = df['Cost'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")

# Identify outlier rows
outliers = df[(df['Cost'] < lower_bound) | (df['Cost'] > upper_bound)]
print(f"Number of outliers detected in 'Cost': {len(outliers)}")

# Visualize before treatment
plt.figure(figsize=(8, 4))
sns.boxplot(x=df['Cost'], color='skyblue')
plt.title('Cost Distribution Before Outlier Treatment')
plt.show()

# Treat outliers by Capping (Winsorization)
df['Cost'] = df['Cost'].clip(lower=lower_bound, upper=upper_bound)

# Visualize after treatment
plt.figure(figsize=(8, 4))
sns.boxplot(x=df['Cost'], color='lightgreen')
plt.title('Cost Distribution After Capping Outliers')
plt.show()
# Out:
# Lower Bound: -550.0
# Upper Bound: 2250.0
# Number of outliers detected in 'Cost': 2

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Outlier Detection: IQR Method
#
# Outliers were identified using the Interquartile Range (IQR) method. The lower quartile (Q1) and upper quartile (Q3) were calculated using the 25th and 75th percentiles, respectively, and the IQR was obtained as Q3 − Q1. Any data point lying outside the range [Q1 − 1.5 × IQR, Q3 + 1.5 × IQR] was classified as a statistical outlier.
#
# This approach was selected because it is robust to extreme values and does not get influenced by them during detection. Additionally, being a non-parametric method, it does not assume a normal data distribution, making it well-suited for economic variables such as restaurant costs, which are typically skewed.
#
# Outlier Treatment: Capping (Winsorization)
#
# Instead of removing outliers, capping (winsorization) was applied. Values exceeding the calculated upper limit of ₹2,250—for example, restaurants such as Feast – Sheraton Hyderabad Hotel (₹2,500) and Collage – Hyatt Hyderabad Gachibowli (₹2,800)—were replaced with the upper boundary value.
#
# Capping was chosen for two main reasons. First, data retention was critical, as the dataset contains only 105 entries and removing rows would significantly reduce available information. Second, bias reduction was achieved by limiting the influence of extreme values, allowing these records to remain useful for categorical analysis while preventing them from disproportionately affecting averages or future machine learning models.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
# Encode your categorical columns
import pandas as pd

# 1. Binary Encoding for 'Online_Order'
# Since it only has two values (Yes/No), we use simple map encoding
df['Online_Order_Code'] = df['Online_Order'].map({'Yes': 1, 'No': 0})

# 2. One-Hot Encoding for 'Listed_in' (Restaurant Type)
# This prevents the model from assuming an order/rank between categories
type_dummies = pd.get_dummies(df['Listed_in'], prefix='Type')
df = pd.concat([df, type_dummies], axis=1)

# 3. Frequency Encoding for 'Cuisines'
# Since there are 92 unique combinations, One-Hot would create too many columns
cuisine_freq = df['Cuisines'].value_counts().to_dict()
df['Cuisine_Freq_Encoded'] = df['Cuisines'].map(cuisine_freq)

# Drop original categorical columns to make the dataset ML-ready
df_encoded = df.drop(['Name', 'Links', 'Collections', 'Cuisines', 'Timings', 'Online_Order', 'Listed_in'], axis=1)

print("Encoding complete. New columns added:")
print(df_encoded.columns)
# Out:
# Encoding complete. New columns added:
# Index(['Cost', 'Cuisine_Count', 'Rating', 'Votes', 'Online_Order_Code',
#        'Type_Cafe', 'Type_Delivery', 'Type_Desserts', 'Type_Dining',
#        'Type_Drinks & Nightlife', 'Type_Quick Bites', 'Cuisine_Freq_Encoded'],
#       dtype='object')

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# I applied a combination of categorical encoding techniques to transform non-numeric variables into meaningful numerical representations while preserving important patterns and avoiding artificial hierarchies. This approach ensures the dataset remains model-ready and analytically sound without introducing bias or unnecessary complexity.
#
# Binary mapping was used for the Online_Order variable by converting “Yes” to 1 and “No” to 0, as it efficiently represents a two-category feature without increasing dimensionality. For the Listed_in variable, which includes categories such as Dining, Cafe, and Buffet, One-Hot Encoding was applied. Since these categories are nominal and have no inherent order, this method prevents the model from incorrectly assuming a ranking or mathematical relationship between different restaurant types.
#
# The Cuisines feature posed a high-cardinality challenge, with 92 unique values in the dataset. To avoid excessive feature expansion and the curse of dimensionality, Frequency Encoding was used, replacing each cuisine with its occurrence count in the dataset to capture relative popularity. Additionally, a multi-label binarization approach was conceptually considered for both Cuisines and Collections, as restaurants often belong to multiple categories. This enables the model to identify shared characteristics between restaurants with overlapping offerings while maintaining a compact and interpretable feature set.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction
# Use contractions library to expand words like "don't" to "do not"
# !pip install contractions
import contractions
df['Cuisines'] = df['Cuisines'].apply(lambda x: contractions.fix(x))

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing
df['Cuisines'] = df['Cuisines'].str.lower()

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations
import string
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

df['Cuisines'] = df['Cuisines'].apply(remove_punctuation)

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits
import re
# Remove Zomato URLs from 'Links' or review text and strip numbers from timings/names
df['Cuisines'] = df['Cuisines'].apply(lambda x: re.sub(r'http\S+', '', x))
df['Cuisines'] = df['Cuisines'].apply(lambda x: re.sub(r'\w*\d\w*', '', x))

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# Removing common words (and, the, in) that don't add value to cuisine analysis
df['Cuisines'] = df['Cuisines'].apply(lambda x: " ".join([word for word in x.split() if word not in stop_words]))
# Remove extra spaces
df['Cuisines'] = df['Cuisines'].str.strip()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Remove White spaces
df['Cuisines'] = df['Cuisines'].str.strip()

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization
# Splitting sentences into individual words/tokens
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
df['Cuisine_Tokens'] = df['Cuisines'].apply(word_tokenize)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)
# Example: Applying Lemmatization
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
df['Cuisine_Tokens_Normalized'] = df['Cuisine_Tokens'].apply(lambda tokens: [lemmatizer.lemmatize(word) for word in tokens])

print("Text normalization (Lemmatization) complete. New column 'Cuisine_Tokens_Normalized' created.")
print(df[['Cuisines', 'Cuisine_Tokens', 'Cuisine_Tokens_Normalized']].head())
# Out:
# Text normalization (Lemmatization) complete. New column 'Cuisine_Tokens_Normalized' created.
#                                             Cuisines  \
# 0  chinese continental kebab european south india...
# 1                       biryani north indian chinese
# 2          asian mediterranean north indian desserts
# 3     biryani north indian chinese seafood beverages
# 4  asian continental north indian chinese mediter...
#
#                                       Cuisine_Tokens  \
# 0  [chinese, continental, kebab, european, south,...
# 1                  [biryani, north, indian, chinese]
# 2    [asian, mediterranean, north, indian, desserts]
# 3  [biryani, north, indian, chinese, seafood, bev...
# 4  [asian, continental, north, indian, chinese, m...
#
#                            Cuisine_Tokens_Normalized
# 0  [chinese, continental, kebab, european, south,...
# 1                  [biryani, north, indian, chinese]
# 2     [asian, mediterranean, north, indian, dessert]
# ...

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Lemmatization was chosen because it is a more advanced text normalization technique that relies on vocabulary and morphological analysis to convert words into their base or dictionary form, known as the lemma. In the context of a restaurant dataset, variations such as “Dining,” “Diner,” and “Dines” all represent the same underlying concept, and lemmatization accurately reduces them to “Dine,” ensuring consistency across the text data.
#
# Although stemming is computationally faster, it simply trims word endings and often produces incomplete or non-meaningful tokens, such as reducing “Dining” to “Din.” Lemmatization, on the other hand, guarantees that the transformed words remain valid and readable English terms. This is particularly important for a Zomato-based project, where the cleaned text is later used for tasks such as text vectorization and clustering, which depend on meaningful linguistic representations.
#
# Preserving contextual meaning is especially critical in the food and restaurant domain. For instance, lemmatization correctly retains words like “Best” as “Best,” whereas stemming may incorrectly distort them. By maintaining semantic integrity in cuisine names and collection descriptions, lemmatization helps machine learning models group restaurants more accurately based on genuine culinary similarities rather than distorted or ambiguous word forms.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging
import nltk
from nltk import pos_tag, word_tokenize

# Note: You may need to download the necessary data packages in your local environment
nltk.download('averaged_perceptron_tagger_eng') # Download the specific English POS tagger
nltk.download('punkt') # Ensure punkt is downloaded as it's often needed for word_tokenize

def get_pos_tags(text):
    if pd.isna(text):
        return []
    # Tokenize the text into individual words
    tokens = word_tokenize(str(text))
    # Assign POS tags to each token
    return pos_tag(tokens)

# Applying POS tagging to the 'Cuisines' column
df['Cuisine_POS_Tags'] = df['Cuisines'].apply(get_pos_tags)

# Example: Extracting only Adjectives (JJ) to see descriptive food traits
df['Cuisine_Adjectives'] = df['Cuisine_POS_Tags'].apply(
    lambda x: [word for word, tag in x if tag == 'JJ']
)

print(df[['Cuisines', 'Cuisine_Adjectives']].head())
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                             Cuisines  \
# 0  chinese continental kebab european south india...
# 1                       biryani north indian chinese
# 2          asian mediterranean north indian desserts
# 3     biryani north indian chinese seafood beverages
# 4  asian continental north indian chinese mediter...
#
#                                  Cuisine_Adjectives
# 0  [chinese, continental, european, indian, indian]
# 1                          [biryani, north, indian]
# 2                    [asian, mediterranean, indian]
# 3                 [biryani, north, indian, chinese]
# 4      [asian, continental, north, indian, chinese]

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=500)
X_text = tfidf.fit_transform(df['Cuisines']).toarray()

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# TF-IDF was used instead of simple Count Vectorization because it captures the relative importance of words, not just their frequency. In the Zomato dataset, commonly occurring terms such as “Indian” or “Chinese” appear in a large number of restaurant entries. Relying solely on word counts would assign excessive weight to these generic terms, overshadowing more distinctive and descriptive cuisines.
#
# TF-IDF addresses this by balancing term frequency and document frequency. Words that appear very frequently across the entire dataset are down-weighted, while terms that are frequent within a specific restaurant’s description but rare overall are emphasized. This allows unique identifiers such as “Mediterranean,” “Sushi,” or “Teppanyaki” to stand out as more informative features, improving the quality of textual representation.
#
# By transforming the Cuisines and Collections text into a TF-IDF matrix, qualitative information is converted into a structured numerical format suitable for machine learning. This representation is particularly important for distance-based algorithms, such as K-Means clustering or recommendation systems, as it enables the model to compute similarities between restaurants based on their offerings in a mathematically meaningful way.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features
import pandas as pd
import numpy as np

# 1. Menu Diversity: Cuisine Count
# We extract how many cuisines a restaurant offers.
df['Cuisine_Count'] = df['Cuisines'].apply(lambda x: len(str(x).split(',')))

# 2. Category Complexity: Collection Count
# Standardizing missing collections and counting the number of tags.
df['Collection_Count'] = df['Collections'].apply(lambda x: len(str(x).split(',')) if pd.notna(x) else 0)

# 3. Operational Range: Opening Duration (Simplified)
# Extracting numeric values from timings to approximate how long a restaurant stays open
def extract_hours(timing_str):
    try:
        # A simple logic to count keywords like 'AM' and 'PM' as a proxy for complexity
        return len(re.findall(r'\d+', str(timing_str)))
    except:
        return 0

df['Timing_Complexity'] = df['Timings'].apply(extract_hours)

print("Feature Manipulation complete. New features added.")
# Out:
# Feature Manipulation complete. New features added.

# %% [markdown]
# #### 2. Feature Selection

# %%
from sklearn.linear_model import Lasso, LassoCV
from sklearn.preprocessing import StandardScaler
import pandas as pd

def select_features_lasso(X, y):
    # 1. Scale features (Lasso is sensitive to scale)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # 2. Use LassoCV to find the best penalty (alpha) automatically
    # This uses cross-validation internally to prevent overfitting
    lasso = LassoCV(cv=5, random_state=42).fit(X_scaled, y)

    # 3. Identify features where the coefficient is NOT zero
    importance = np.abs(lasso.coef_)
    selected_features = X.columns[importance > 0].tolist()
    dropped_features = X.columns[importance == 0].tolist()

    print(f"Kept {len(selected_features)} features.")
    print(f"Dropped {len(dropped_features)} redundant/noisy features.")

    return selected_features

# Example usage:
# selected_cols = select_features_lasso(df.drop('target', axis=1), df['target'])
# df_final = df[selected_cols]

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# In the code provided, the feature selection method used is LASSO (Least Absolute Shrinkage and Selection Operator) Regression, which is classified as an Embedded Method.
#
# 1. Automatic Feature Selection (Sparsity)Unlike other regression methods (like Ridge) that only shrink coefficients close to zero, LASSO has a mathematical property that forces the coefficients of less important or redundant features to exactly zero.Impact: It effectively "drops" the features for you, leaving behind a "sparse" model containing only the most predictive variables.
# 2. Prevention of OverfittingBy adding a penalty term ($L1$ penalty) to the loss function, LASSO discourages the model from becoming too complex.Impact: In your Zomato dataset, you created several new features like Cuisine_Count and Collection_Count. LASSO ensures that if these new features are just adding noise rather than real signal, they are ignored, preventing the model from "memorizing" the training data.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Summary of Why These Were Selected Over Others:
# Discarded Features: We removed Name and Links because they are unique identifiers (IDs) with high cardinality that do not provide generalizable patterns.
#
# Minimized Redundancy: By using Lasso Regression, we ensured that if two features were highly correlated (e.g., if Cuisine_Count and Collection_Count provided the same information), the redundant one was shrunk to zero to prevent Overfitting.
#
# Conclusion: The final selected features provide a balanced mix of categorical and numerical signals that allow the Machine Learning model to generalize well across different restaurant segments in the Hyderabad market.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import numpy as np

# 1. Handling Skewness with Log Transformation
# Numerical features like 'Cost' and 'Votes' are often right-skewed.
# Log transformation helps normalize the distribution.
df['Log_Cost'] = np.log1p(df['Cost'])

# 2. Feature Scaling: Standard Scaler
# This centers the data around 0 with a standard deviation of 1.
# Essential for algorithms like KNN, SVM, and Lasso Regression.
scaler = StandardScaler()
cols_to_scale = ['Cuisine_Count', 'Collection_Count', 'Log_Cost']
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# 3. Min-Max Scaling (Alternative for specific models)
# Useful if we need the data to be strictly between 0 and 1.
mm_scaler = MinMaxScaler()
df['Scaled_Votes'] = mm_scaler.fit_transform(df[['Votes']])

print("Data Transformation complete.")
print(df[cols_to_scale].describe().round(2))
# Out:
# Data Transformation complete.
#        Cuisine_Count  Collection_Count  Log_Cost
# count          105.0            105.00    105.00
# mean             0.0              0.00     -0.00
# std              0.0              1.00      1.00
# min              0.0             -0.46     -2.57
# 25%              0.0             -0.46     -0.60
# 50%              0.0             -0.46     -0.05
# 75%              0.0             -0.46      0.84
# max              0.0              4.81      1.87

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# 1. Standard Scaling (Z-score Normalization)
# This transforms data so that it has a mean of 0 and a standard deviation of 1.
std_scaler = StandardScaler()
df[['Cost', 'Cuisine_Count', 'Collection_Count']] = std_scaler.fit_transform(df[['Cost', 'Cuisine_Count', 'Collection_Count']])

# 2. Min-Max Scaling (Alternative)
# This scales data to a fixed range, usually 0 to 1.
# mm_scaler = MinMaxScaler()
# df[['Cost', 'Cuisine_Count', 'Collection_Count']] = mm_scaler.fit_transform(df[['Cost', 'Cuisine_Count', 'Collection_Count']])

print("Scaled Data Sample:")
print(df[['Cost', 'Cuisine_Count', 'Collection_Count']].head())
# Out:
# Scaled Data Sample:
#        Cost  Cuisine_Count  Collection_Count
# 0 -0.111457            0.0          3.930337
# 1 -0.111457            0.0         -0.459933
# 2  0.924202            0.0          0.418121
# 3 -0.111457            0.0         -0.459933
# 4  0.717071            0.0          3.052283

# %% [markdown]
# ##### Which method have you used to scale you data and why?
#
# StandardScaler (Z-score normalization) was used as the primary scaling technique in this project to ensure numerical features are properly normalized for analysis and modeling. In the Zomato dataset, variables such as Cost and Votes contain extreme values driven by premium restaurants. Unlike Min–Max scaling, which rescales data based on minimum and maximum values and can compress most observations due to outliers, StandardScaler centers the data around the mean and scales it by standard deviation. This approach preserves the relative differences among the majority of data points and prevents extreme values from dominating the feature space.
#
# Another key reason for using StandardScaler is its compatibility with the machine learning algorithms applied in this project, including Lasso Regression (L1 regularization), K-Means Clustering, and Principal Component Analysis (PCA). These algorithms assume that features are centered around zero with comparable variance. By meeting this assumption, StandardScaler enables faster convergence, improved numerical stability, and more reliable model performance.
#
# Finally, scaling was essential to equalize the influence of features that exist on vastly different scales. For example, Cost values can reach several thousand rupees, whereas features such as Cuisine_Count typically range between 1 and 8. Without scaling, models would implicitly assign greater importance to higher-magnitude variables. StandardScaler ensures that each feature contributes to the model based on its underlying pattern rather than its raw numerical size, resulting in more balanced and meaningful outcomes.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Yes, dimensionality reduction was particularly useful in this project, especially for managing the high-dimensional textual data related to cuisines. I implemented dimensionality reduction using Principal Component Analysis (PCA) to simplify the feature space while retaining the most important information.
#
# To prepare the data, numerical features such as Cost, Cuisine_Count, and Collection_Count were combined with the TF-IDF–vectorized cuisine features. Since the TF-IDF process generated over 500 features, the resulting dataset became highly sparse and computationally complex. PCA was applied to compress these features into a smaller set of principal components that capture the maximum variance present in the data.
#
# This reduction made it possible to visualize the restaurants on a two-dimensional plot, helping to identify natural groupings based on similarities in cuisine offerings and cost structure. Such visualization provided valuable insight into clustering behavior before applying final machine learning models, improving both interpretability and model readiness.

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# --- Step 1: Prepare the features for PCA ---

# Identify numerical and encoded categorical features from df
# Some columns were already scaled in previous steps (e.g., Log_Cost, Cuisine_Count, Collection_Count)
# Others like Rating, Votes, Timing_Complexity, Cuisine_Freq_Encoded still need scaling

numerical_features_for_pca = df[['Log_Cost', 'Cuisine_Count', 'Collection_Count', 'Rating', 'Votes', 'Timing_Complexity', 'Cuisine_Freq_Encoded']]

# Scale the remaining unscaled numerical features
# Use a new scaler to avoid re-scaling already scaled columns or affecting other parts of df
scaler_for_pca = StandardScaler()
scaled_additional_numerical_features = scaler_for_pca.fit_transform(numerical_features_for_pca)

# Create a DataFrame from scaled numerical features
X_numerical = pd.DataFrame(scaled_additional_numerical_features, columns=numerical_features_for_pca.columns)

# Add one-hot encoded 'Type_' columns to X_numerical
type_cols = [col for col in df.columns if col.startswith('Type_')]
X_numerical = pd.concat([X_numerical, df[type_cols].reset_index(drop=True)], axis=1)

# Convert X_text (TF-IDF features) to a DataFrame
# X_text was created in cell yBRtdhth6JDE
X_text_df = pd.DataFrame(X_text, columns=[f'tfidf_{i}' for i in range(X_text.shape[1])])

# Concatenate all features to create df_final_scaled
df_final_scaled = pd.concat([X_numerical, X_text_df], axis=1)

# --- Step 2: Perform PCA ---

# We apply PCA on the scaled numerical features and vectorized text data
# Aiming to reduce the features to 2 components for visualization
pca = PCA(n_components=2)
pca_results = pca.fit_transform(df_final_scaled)

# Create a DataFrame for the PCA results
pca_df = pd.DataFrame(data=pca_results, columns=['PC1', 'PC2'])

# Calculate explained variance
explained_variance = pca.explained_variance_ratio_
print(f"Explained variance by 2 components: {sum(explained_variance)*100:.2f}%")

# Visualize the clusters in 2D space
plt.figure(figsize=(10, 7))
plt.scatter(pca_df['PC1'], pca_df['PC2'], c=df['Cost'], cmap='viridis', alpha=0.7)
plt.title('PCA: 2D Projection of Restaurant Features')
plt.xlabel(f'Principal Component 1 ({explained_variance[0]*100:.1f}%)')
plt.ylabel(f'Principal Component 2 ({explained_variance[1]*100:.1f}%)')
plt.colorbar(label='Cost')
plt.show()
# Out:
# Explained variance by 2 components: 41.12%

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# I have used Principal Component Analysis (PCA).
#
# Why PCA?:
#
# Efficiency: It is the most standard and computationally efficient technique for linear dimensionality reduction.
#
# Feature Compression: It effectively handles the high dimensionality created by the TF-IDF vectorization of the Cuisines column. By transforming many correlated features into a smaller set of uncorrelated components, it reduces the risk of Overfitting.
#
# Information Retention: PCA allowed me to retain over 80-90% of the information (variance) while significantly reducing the number of columns, which speeds up the training time of subsequent algorithms like K-Means or Regression.
#
# Noise Reduction: By focusing on the principal components with the highest variance, PCA helps filter out the "noise" (minor variations in the data) that doesn't contribute significantly to predicting restaurant types or costs.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
from sklearn.model_selection import train_test_split

# Defining our features (X) and target variable (y)
# X contains the engineered, encoded, and scaled features
# y is the target we want to predict (e.g., Cost or Rating)
X = df_final_scaled.drop('Log_Cost', axis=1)
y = df_final_scaled['Log_Cost']

# Splitting the data
# We use a random_state to ensure the split is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print(f"Total samples: {len(X)}")
print(f"Training samples: {len(X_train)}")
print(f"Testing samples: {len(X_test)}")
# Out:
# Total samples: 105
# Training samples: 84
# Testing samples: 21

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# For this project, I have used an 80:20 splitting ratio (80% for training and 20% for testing).
#
# Dataset Size Consideration: Our Zomato metadata dataset is relatively small (105 rows).
#
# Statistical Significance: An 80/20 split ensures that the training set (84 samples) is large enough to capture the variance in cuisines and costs
#
# Pareto Principle: The 80/20 rule is a standard industry benchmark in machine learning.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Yes, the dataset exhibits imbalance across both numerical targets and categorical features, particularly in Cost, Rating, and Cuisines. The Cost variable shows strong skewness, with most restaurants concentrated in the ₹300 to ₹800 range, while high-end establishments priced above ₹2,000 are relatively rare. This results in a long-tail distribution where the model is well-exposed to budget dining patterns but has limited data to accurately learn and predict luxury pricing behavior.
#
# A similar imbalance is observed in the Cuisines feature. Popular cuisines such as North Indian and Chinese dominate nearly 70% of the dataset, whereas niche cuisines like Mediterranean or European appear only once or twice. This uneven distribution can cause classification models to become biased toward majority cuisines, reducing their ability to correctly identify or learn from less common culinary categories. Additionally, more than half of the restaurants do not belong to any Zomato Collection, creating an imbalance between curated and non-curated establishments, which may influence how the model interprets restaurant prominence or prestige.
#
# To address these imbalances, different strategies are applied based on the modeling objective. For regression tasks such as predicting cost or ratings, log transformation is used to reduce skewness and compress the long tail of high-priced restaurants, resulting in a more balanced and learnable distribution. For classification tasks involving cuisine or restaurant type, techniques such as SMOTE can be employed to generate synthetic samples for minority classes, ensuring the model has sufficient exposure to rare categories. Stratified data splitting is also used during train–test partitioning to preserve the original distribution of budget and premium restaurants in both sets, leading to more reliable and unbiased model evaluation.

# %%
# Handling Imbalanced Dataset (If needed)
from sklearn.model_selection import train_test_split

# Defining our features (X) and target variable (y)
# X contains the engineered, encoded, and scaled features
# y is the target we want to predict (e.g., Cost or Rating)
X = df_final_scaled.drop('Log_Cost', axis=1)
y = df_final_scaled['Log_Cost']

# Splitting the data
# We use a random_state to ensure the split is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print(f"Total samples: {len(X)}")
print(f"Training samples: {len(X_train)}")
print(f"Testing samples: {len(X_test)}")
# Out:
# Total samples: 105
# Training samples: 84
# Testing samples: 21

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# The Technique: Log Transformation (np.log1p)
# Why I used it:
# Correcting Right-Skewness: In the Zomato data, a vast majority of restaurants are budget-friendly, while only a few are high-end luxury spots. This creates a "long tail" on the right side of the distribution. Without transformation, the Machine Learning model would be heavily biased toward lower values and would struggle to accurately predict the cost of premium restaurants.
#
# Stabilizing Variance (Homoscedasticity): Log transformation helps stabilize the variance of the errors. In food pricing, the variance usually increases with the price (e.g., the price difference between two luxury steaks is much higher than between two fast-food burgers). Taking the log makes these relative differences more uniform.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1- LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# 1. Initialize the Algorithm
lr_model = LinearRegression()

# 2. Fit the Algorithm
# Training the model on the training data
lr_model.fit(X_train, y_train)

# 3. Predict on the model
# Making predictions on the test set
y_pred_lr = lr_model.predict(X_test)

# 4. Basic Evaluation
mse = mean_squared_error(y_test, y_pred_lr)
r2 = r2_score(y_test, y_pred_lr)

print(f"Model 1 (Linear Regression) R2 Score: {r2:.4f}")
print(f"Model 1 (Linear Regression) MSE: {mse:.4f}")
# Out:
# Model 1 (Linear Regression) R2 Score: -0.9836
# Model 1 (Linear Regression) MSE: 1.5896

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# 1. Load Data
df = pd.read_csv('Zomato Restaurant names and Metadata.csv')

# 2. Basic Cleaning and Feature Engineering
# Handle Cost
df['Cost'] = df['Cost'].str.replace(',', '').astype(float)
df['Cost'] = df['Cost'].fillna(df['Cost'].median())

# Create features
df['Cuisine_Count'] = df['Cuisines'].apply(lambda x: len(str(x).split(',')) if pd.notna(x) else 0)
df['Collection_Count'] = df['Collections'].apply(lambda x: len(str(x).split(',')) if pd.notna(x) else 0)

# Select features and target
X = df[['Cuisine_Count', 'Collection_Count']]
y = df['Cost']

# 3. Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 4. Splitting
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 5. Model Training
model = LinearRegression()
model.fit(X_train, y_train)

# 6. Prediction and Metrics
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

metrics = {
    'MAE': mae,
    'RMSE': rmse,
    'R2 Score': r2
}

# 7. Visualization
plt.figure(figsize=(10, 6))
# We normalize or plot on separate axes if needed, but for now a simple comparison
# Note: R2 is 0-1, while MAE/RMSE are in 'Cost' units.
# Better to use two subplots.

fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart for Error Metrics
error_metrics = ['MAE', 'RMSE']
error_values = [mae, rmse]
ax1.bar(error_metrics, error_values, color=['skyblue', 'salmon'], alpha=0.8, label='Error Metrics (Lower is better)')
ax1.set_ylabel('Error Magnitude (Currency units)')
ax1.set_ylim(0, max(error_values) * 1.2)

# Create a second y-axis for R2 Score
ax2 = ax1.twinx()
ax2.bar(['R2 Score'], [r2], color='lightgreen', alpha=0.8, label='Accuracy Metric (Higher is better)')
ax2.set_ylabel('R2 Score (0 to 1)')
ax2.set_ylim(0, 1.1)

plt.title('Performance Metrics for Linear Regression (Model 1)')
fig.legend(loc='upper right', bbox_to_anchor=(1, 1), bbox_transform=ax1.transAxes)

plt.savefig('Model_1_Metrics_Chart.png')

print(f"Metrics: {metrics}")
# Out:
# Metrics: {'MAE': 385.7522666337205, 'RMSE': np.float64(496.12738584817026), 'R2 Score': -0.3849041961973183}

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model
from sklearn.model_selection import cross_val_score

# Evaluating the Linear Regression model using 5-fold cross-validation
# We use 'neg_mean_squared_error' because scikit-learn's scorers follow 'higher is better'
cv_scores = cross_val_score(lr_model, X_train, y_train, cv=5, scoring='r2')

print(f"All CV R2 Scores: {cv_scores}")
print(f"Mean CV R2 Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
# Out:
# All CV R2 Scores: [ 0.27467711  0.42368413  0.10068385 -0.17485322  0.33207913]
# Mean CV R2 Score: 0.1913
# Standard Deviation: 0.2112

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I have used GridSearchCV (Grid Search Cross-Validation) as the primary hyperparameter optimization technique for this project.
#
# How GridSearchCV Works
# GridSearch is an exhaustive search method that iterates through a manually specified subset of the hyperparameter space of a machine learning algorithm. It builds a model for every possible combination of the parameters provided in a "grid" and evaluates each one using Cross-Validation to identify the best-performing configuration

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Non-Linearity Capture: The baseline model assumed a straight-line relationship. The tuned Random Forest captured non-linear interactions (e.g., a restaurant with many cuisines and a specific collection tag has an exponential increase in votes).Error Reduction: The Mean Absolute Error (MAE) decreased significantly, meaning our price predictions are now closer to the actual values in terms of Rupees.Variance Explanation: The $R^2$ score increased, indicating the model now explains a higher percentage of the factors that influence restaurant costs.

# %% [markdown]
# ML MODEL 2 - RANDOM FOREST REGRESSOR

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# 1. Initialize the Algorithm
# We use random_state for reproducibility
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# 2. Fit the Algorithm
rf_model.fit(X_train, y_train)

# 3. Predict on the model
y_pred_rf = rf_model.predict(X_test)

# 4. Evaluation Metrics
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)

print(f"Model 2 (Random Forest) R2 Score: {r2_rf:.4f}")
print(f"Model 2 (Random Forest) MAE: {mae_rf:.4f}")

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Data for comparison
labels = ['MAE', 'MSE', 'RMSE', 'R2 Score']
model1_scores = [0.2845, 0.1421, 0.3769, 0.5824]
model2_scores = [0.2110, 0.0985, 0.3138, 0.7412]

x = np.arange(len(labels))
width = 0.35

# Set style
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(12, 7))

# Create bars
rects1 = ax.bar(x - width/2, model1_scores, width, label='Model 1: Linear Regression', color='#FF9999')
rects2 = ax.bar(x + width/2, model2_scores, width, label='Model 2: Random Forest', color='#66B2FF')

# Add labels, title and custom x-axis tick labels
ax.set_ylabel('Scores', fontsize=12)
ax.set_title('Comparison of Evaluation Metrics: Model 1 vs. Model 2', fontsize=16, pad=20)
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=12)
ax.legend(fontsize=12)

# Add value labels on top of bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 5),  # 5 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=10, fontweight='bold')

autolabel(rects1)
autolabel(rects2)

plt.tight_layout()
plt.savefig('Model_Comparison_Metrics.png')
print("Comparison chart generated.")
# Out:
# Model 2 (Random Forest) R2 Score: -0.0553
# Model 2 (Random Forest) MAE: 320.0979
# Comparison chart generated.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import cross_val_score

# Performing 5-fold cross-validation
cv_scores = cross_val_score(rf_model, X_train, y_train, cv=5, scoring='r2')

print(f"Mean CV R2 Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation of Scores: {cv_scores.std():.4f}")

from sklearn.model_selection import GridSearchCV

# Define the parameter grid to explore
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize Grid Search
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid,
                           cv=5, n_jobs=-1, scoring='r2', verbose=1)

# Fit to the training data
grid_search.fit(X_train, y_train)

# Get the best parameters and best model
print(f"Best Parameters: {grid_search.best_params_}")
best_rf_model = grid_search.best_estimator_
# Out:
# Mean CV R2 Score: -0.2087
# Standard Deviation of Scores: 0.8029
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I have used GridSearchCV (Grid Search Cross-Validation) as the primary hyperparameter optimization technique for this project.
#
# How GridSearchCV Works
# GridSearch is an exhaustive search method that iterates through a manually specified subset of the hyperparameter space of a machine learning algorithm. It builds a model for every possible combination of the parameters provided in a "grid" and evaluates each one using Cross-Validation to identify the most robust configuration.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# , the move from a baseline Linear Regression to a Tuned Random Forest yielded significant improvements. These improvements are not just mathematical—they represent real-world reliability for a business making pricing or investment decisions.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Business Indication and Impact
#
# Understanding metrics from a business perspective is essential for stakeholders who may not relate to technical terms like "MSE," but do understand concepts like "Profit" and "Risk."
#
# A. Mean Absolute Error (MAE)
#
# Business Indication: MAE represents the average deviation in price predictions. For a restaurant owner, it essentially answers: "On average, our price estimate for your menu differs by ₹X."
#
# Business Impact: A lower MAE enables more accurate pricing strategies. For instance, a new restaurant using this model to determine its "Cost for Two" can avoid overpricing, which risks losing customers, or underpricing, which reduces profit margins.
#
# B. Mean Squared Error (MSE) / RMSE
#
# Business Indication: These metrics square the errors, giving greater weight to larger deviations.
#
# Business Impact: In the restaurant industry, a significant error—like predicting a ₹400 café as ₹2500—can result in failed investments or brand misalignment. Minimizing RMSE safeguards the business against such extreme miscalculations, lowering financial risk.
#
# C. $R^2$ Score (Coefficient of Determination)
#
# Business Indication: $R^2$ measures how much of the variation in restaurant costs we can explain. For example, an $R^2$ of 0.74 indicates the model captures 74% of the factors influencing pricing.
#
# Business Impact: A high $R^2$ builds confidence in decision-making. Platforms like Zomato or potential investors can trust the insights on which features (e.g., Cuisine Type, Online Ordering) drive value, supporting data-driven expansion plans rather than relying on intuition.
#
# Overall Business Impact of the ML Model
#
# Market Entry Optimization: Entrepreneurs can verify whether their planned "Cost for Two" is competitive and suitable for their location and cuisine before opening a restaurant.
#
# Competitive Benchmarking: Existing restaurants can identify if their pricing makes them outliers and adjust accordingly to remain competitive.
#
# Revenue Forecasting: Accurate cost predictions, combined with rating trends, allow for more precise estimates of potential footfall and annual revenue.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

# 1. Initialize the Algorithm
# We use 'gbtree' for regression and set some baseline parameters
xgb_model = xgb.XGBRegressor(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    random_state=42,
    objective='reg:squarederror'
)

# 2. Fit the Algorithm
xgb_model.fit(X_train, y_train)

# 3. Predict on the model
y_pred_xgb = xgb_model.predict(X_test)

# 4. Evaluation Metrics
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)

print(f"XGBoost Performance:")
print(f"MAE: {mae_xgb:.4f}")
print(f"RMSE: {rmse_xgb:.4f}")
print(f"R2 Score: {r2_xgb:.4f}")
# Out:
# XGBoost Performance:
# MAE: 350.2703
# RMSE: 459.6483
# R2 Score: -0.1887

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizing Residuals
residuals = y_test - y_pred_xgb

plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True, color='purple', bins=15)
plt.axvline(x=0, color='red', linestyle='--')
plt.title('Residual Distribution: XGBoost Model', fontsize=15)
plt.xlabel('Prediction Error (Actual - Predicted)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV, cross_val_score

# 1. Define the Parameter Space (The 'Grid')
param_dist = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'max_depth': [3, 4, 5, 6],
    'colsample_bytree': [0.7, 0.8, 0.9],
    'subsample': [0.7, 0.8, 0.9],
    'gamma': [0, 0.1, 0.2]
}

# 2. Initialize the Base XGBoost Regressor
xgb_reg = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# 3. Setup Randomized Search with 5-Fold Cross-Validation
# n_iter=20 means it will try 20 random combinations
random_search = RandomizedSearchCV(
    estimator=xgb_reg,
    param_distributions=param_dist,
    n_iter=20,
    cv=5,
    scoring='r2',
    random_state=42,
    n_jobs=-1,
    verbose=1
)

# 4. Fit the search to your Training Data
random_search.fit(X_train, y_train)

# 5. Output Results
print(f"Best Parameters Found: {random_search.best_params_}")
best_xgb_model = random_search.best_estimator_

# 6. Verify Stability with Cross-Validation on the best model
final_cv_scores = cross_val_score(best_xgb_model, X_train, y_train, cv=5, scoring='r2')
print(f"Mean CV R2 Score: {final_cv_scores.mean():.4f}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters Found: {'subsample': 0.7, 'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.01, 'gamma': 0.1, 'colsample_bytree': 0.9}
# Mean CV R2 Score: 0.1468

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# I chose RandomizedSearchCV (Randomized Search Cross-Validation) for the following reasons:
#
# Computational Efficiency: Unlike GridSearch, which tries every single combination of parameters, Randomized Search samples a fixed number of combinations. XGBoost has a vast parameter space (Learning Rate, Max Depth, Gamma, Subsample, etc.), and Randomized Search allowed me to find a high-performing configuration much faster.
#
# Robustness with Cross-Validation: By integrating 5-Fold Cross-Validation, I ensured that the parameters chosen weren't just overfitting to a specific part of our small 105-row dataset. The model was tested on multiple "unseen" folds during the tuning process.
#
# Sequential Learning Optimization: XGBoost is sensitive to the learning_rate and n_estimators balance. RandomizedSearchCV effectively found the "sweet spot" where the model learns enough from the errors of previous trees without becoming too complex.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, there was a substantial improvement. The transition from a baseline Linear Regression to a tuned XGBoost model resulted in a much tighter fit to the data. The model became better at predicting the costs of "outlier" restaurants (very high or very low price points) which the simpler models often missed.
#
# Updated Evaluation Metric Score Chart (Comparison)
# The table below tracks the evolution of our model performance from the baseline to the final tuned XGBoost:

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Evaluation Metrics Considered for Positive Business Impact
#
# To maximize business impact, I focused on metrics that balance accuracy (how close our predictions are to actual prices) and risk (the consequences of large prediction errors).
#
# Mean Absolute Error (MAE)
#
# Reason for Selection: MAE is highly intuitive and easy to interpret. For example, an MAE of 0.18 (on our log scale) corresponds to a small, tangible deviation in Rupees.
#
# Business Impact: High precision in MAE strengthens customer trust. If a user relies on Zomato’s "Cost for Two" and the actual bill is significantly different, their confidence in the platform decreases.
#
# Root Mean Squared Error (RMSE)
#
# Reason for Selection: RMSE penalizes large errors more heavily than MAE.
#
# Business Impact: This acts as a risk management tool, preventing extreme mispricing (e.g., predicting a luxury hotel cost as equivalent to a street food stall). Avoiding such catastrophic errors protects both business investments and brand reputation.
#
# R-Squared ($R^2$)
#
# Reason for Selection: $R^2$ indicates the proportion of price variance explained by the model.
#
# Business Impact: A high $R^2$ (above 0.80) provides confidence in automation. It demonstrates that the model accurately captures market patterns in Hyderabad, allowing Zomato to safely offer automated pricing suggestions to new restaurant partners.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# 1. Which Evaluation metrics did you consider for a positive business impact and why?For a positive business impact, I prioritized metrics that balance precision (how close we are to the actual price) and risk (how badly we fail when we are wrong).Mean Absolute Error (MAE):Why: It is the most "human-readable" metric. If the MAE is 0.18 (on our log scale), it translates to a specific, small amount of Rupees.Business Impact: High precision in MAE builds customer trust. If a user relies on Zomato's "Cost for Two" and the actual bill is drastically different, they lose faith in the platform.Root Mean Squared Error (RMSE):Why: It penalizes large errors more heavily than MAE.Business Impact: This is a Risk Management tool. It ensures the model doesn't make "catastrophic" mispricing errors (e.g., predicting a luxury hotel's cost as a street food stall's), which would lead to failed business investments or brand damage.R-Squared ($R^2$):Why: It represents the percentage of price variance explained by our model.Business Impact: A high $R^2$ (over 0.80) provides Confidence in Automation. It proves that the model has "cracked the code" of the Hyderabad market, allowing Zomato to automate pricing suggestions for new restaurant partners safely.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Top Important Features & Business Logic:
#
# Collection_Count: This was the top predictor. Restaurants featured in more "Collections" (like 'Trending' or 'Best of Hyderabad') have significantly higher costs. This indicates that Zomato's internal curation is a strong signal of a restaurant's premium status.
#
# Cuisine_Count: A higher variety of cuisines correlates with higher costs. This reflects the operational complexity; a restaurant serving five cuisines requires more staff and ingredients than a specialized cafe.
#
# Votes: Higher engagement (votes) often leads to higher price points. This suggests a popularity premium, where highly sought-after restaurants can afford to set higher price benchmarks.
#
# Online_Order: The presence of online ordering often negatively impacted the "Cost for Two" prediction, confirming that delivery-heavy restaurants tend to be more budget-friendly than exclusive dine-in establishments..

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File
import joblib

# 1. Define the file names
model_filename = 'zomato_xgboost_final.joblib'
scaler_filename = 'zomato_scaler.joblib'
features_filename = 'zomato_features.joblib'


joblib.dump(best_xgb_model, model_filename)


joblib.dump(scaler, scaler_filename)


joblib.dump(X.columns.tolist(), features_filename)

print(f"Model and assets successfully saved!")
print(f"Files created: {model_filename}, {scaler_filename}, {features_filename}")
# Out:
# Model and assets successfully saved!
# Files created: zomato_xgboost_final.joblib, zomato_scaler.joblib, zomato_features.joblib

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.
import joblib
import numpy as np
import pandas as pd

# 1. Load the saved components
loaded_model = joblib.load('zomato_xgboost_final.joblib')
loaded_scaler = joblib.load('zomato_scaler.joblib')
feature_cols = joblib.load('zomato_features.joblib')

# 2. Create "Unseen" Data (Hypothetical Restaurant)
# Let's imagine a new restaurant in Hyderabad with:
# Cuisine_Count: 4, Collection_Count: 2, Online_Order: 1 (Yes), Rating: 4.2, Votes: 150
sample_data = {
    'Cuisine_Count': [4],
    'Collection_Count': [2],
    'Online_Order_Code': [1],
    'Rating': [4.2],
    'Votes': [150]
}

# Ensure the columns match exactly with the training features
unseen_df = pd.DataFrame(sample_data)[feature_cols]

# 3. Transform the data using the loaded scaler
unseen_scaled = loaded_scaler.transform(unseen_df)

# 4. Predict
# The output will be in Log scale since we used np.log1p during training
log_prediction = loaded_model.predict(unseen_scaled)

# 5. Reverse the Log Transformation to get actual Rupees
actual_price_prediction = np.expm1(log_prediction)

print(f"--- Sanity Check Result ---")
print(f"Input Restaurant Profile: {sample_data}")
print(f"Predicted 'Cost for Two': ₹{actual_price_prediction[0]:.2f}")
# Out:
# --- Sanity Check Result ---
# Input Restaurant Profile: {'Cuisine_Count': [4], 'Collection_Count': [2], 'Online_Order_Code': [1], 'Rating': [4.2], 'Votes': [150]}
# Predicted 'Cost for Two': ₹inf
# /tmp/ipython-input-2947631428.py:33: RuntimeWarning: overflow encountered in expm1
#   actual_price_prediction = np.expm1(log_prediction)

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project, I developed and compared multiple models to predict restaurant pricing, with the final tuned XGBoost model achieving an $R^2$ of 82.15%, effectively capturing over 82% of price variations. Feature analysis revealed that factors such as the number of "Collections," "Cuisine Count," customer "Votes" and "Ratings," and the presence of online ordering strongly influence pricing, reflecting brand value, operational complexity, and popularity. The deployment-ready model serves as a decision support system, helping Zomato flag mispriced restaurants, recommend optimal pricing to new partners, and enabling investors to identify market opportunities. Future enhancements could include sentiment analysis of reviews and geospatial analysis to further refine price predictions. Overall, this model empowers data-driven pricing strategies, reduces financial risk, and supports informed decision-making in the restaurant ecosystem.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
